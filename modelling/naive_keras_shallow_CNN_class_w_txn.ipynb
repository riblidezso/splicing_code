# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int32),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
print train_x.shape

txn_x,txn_y = read_my_data(fname='../prepare_data/txn_feat_vect_200.csv')
print txn_x.shape
# Out:
# Loading data...
# (10097, 1600)
# Loading data...
# (10097, 1600)

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,1600,4))
print train_x.shape

full_x=np.concatenate([train_x,txn_x.reshape(-1,1,1600,1)/1000.0],axis=3)
print full_x.shape
# Out:
# (10097, 1, 1600, 4)
# (10097, 1, 1600, 5)

# %%
#make target classes
train_y=(0.5*(np.sign(train_y-0.5)+1)).astype(np.int8)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2

im_size=5

input_dim=full_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(64,1)
window_size=40


model = Sequential()

#Convolution layer
model.add(Convolution2D(100,window_size,im_size, border_mode='valid',
                        input_shape=(1,input_dim,im_size),W_regularizer=l2(0.01)))
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Flatten())
#model.add(Dropout(0.2))

#final layer
model.add(Dense(1, activation='sigmoid'))

#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=5,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=8000
N_test=2000

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,full_x[:N_train],train_y[:N_train],
    full_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/100
# 6400/6400 [==============================] - 11s - loss: 1.8024 - acc: 0.5830 - val_loss: 0.7159 - val_acc: 0.4863
# Epoch 00000: val_loss improved from inf to 0.71591, saving model to best_model
# Epoch 2/100
# 6400/6400 [==============================] - 11s - loss: 1.3872 - acc: 0.6106 - val_loss: 0.6803 - val_acc: 0.6212
# Epoch 00001: val_loss improved from 0.71591 to 0.68026, saving model to best_model
# Epoch 3/100
# 6400/6400 [==============================] - 11s - loss: 1.1249 - acc: 0.6481 - val_loss: 0.6440 - val_acc: 0.6488
# Epoch 00002: val_loss improved from 0.68026 to 0.64402, saving model to best_model
# Epoch 4/100
# 6400/6400 [==============================] - 11s - loss: 0.9733 - acc: 0.6564 - val_loss: 0.6366 - val_acc: 0.6550
# Epoch 00003: val_loss improved from 0.64402 to 0.63663, saving model to best_model
# Epoch 5/100
# 6400/6400 [==============================] - 11s - loss: 0.8758 - acc: 0.6623 - val_loss: 0.6446 - val_acc: 0.6675
# Epoch 00004: val_loss did not improve
# Epoch 6/100
# 6400/6400 [==============================] - 11s - loss: 0.8125 - acc: 0.6734 - val_loss: 0.6310 - val_acc: 0.6719
# Epoch 00005: val_loss improved from 0.63663 to 0.63102, saving model to best_model
# Epoch 7/100
# 6400/6400 [==============================] - 11s - loss: 0.7701 - acc: 0.6781 - val_loss: 0.6244 - val_acc: 0.6906
# Epoch 00006: val_loss improved from 0.63102 to 0.62440, saving model to best_model
# Epoch 8/100
# 6400/6400 [==============================] - 11s - loss: 0.7363 - acc: 0.6856 - val_loss: 0.6227 - val_acc: 0.6687
# Epoch 00007: val_loss improved from 0.62440 to 0.62268, saving model to best_model
# Epoch 9/100
# 6400/6400 [==============================] - 11s - loss: 0.7246 - acc: 0.6784 - val_loss: 0.6337 - val_acc: 0.6663
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 6400/6400 [==============================] - 11s - loss: 0.6991 - acc: 0.6870 - val_loss: 0.6130 - val_acc: 0.6787
# Epoch 00009: val_loss improved from 0.62268 to 0.61298, saving model to best_model
# Epoch 11/100
# 6400/6400 [==============================] - 11s - loss: 0.6849 - acc: 0.6920 - val_loss: 0.6171 - val_acc: 0.6613
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 6400/6400 [==============================] - 11s - loss: 0.6713 - acc: 0.6975 - val_loss: 0.6158 - val_acc: 0.6744
# Epoch 00011: val_loss did not improve
# Epoch 13/100
# 6400/6400 [==============================] - 11s - loss: 0.6577 - acc: 0.7030 - val_loss: 0.6071 - val_acc: 0.6894
# Epoch 00012: val_loss improved from 0.61298 to 0.60707, saving model to best_model
# Epoch 14/100
# 6400/6400 [==============================] - 11s - loss: 0.6488 - acc: 0.7061 - val_loss: 0.6063 - val_acc: 0.6781
# Epoch 00013: val_loss improved from 0.60707 to 0.60629, saving model to best_model
# Epoch 15/100
# 6400/6400 [==============================] - 11s - loss: 0.6429 - acc: 0.7134 - val_loss: 0.6031 - val_acc: 0.6881
# Epoch 00014: val_loss improved from 0.60629 to 0.60305, saving model to best_model
# Epoch 16/100
# 6400/6400 [==============================] - 11s - loss: 0.6325 - acc: 0.7197 - val_loss: 0.5970 - val_acc: 0.6837
# Epoch 00015: val_loss improved from 0.60305 to 0.59698, saving model to best_model
# Epoch 17/100
# 6400/6400 [==============================] - 11s - loss: 0.6254 - acc: 0.7163 - val_loss: 0.5949 - val_acc: 0.6894
# Epoch 00016: val_loss improved from 0.59698 to 0.59488, saving model to best_model
# Epoch 18/100
# 6400/6400 [==============================] - 11s - loss: 0.6189 - acc: 0.7280 - val_loss: 0.5928 - val_acc: 0.7025
# Epoch 00017: val_loss improved from 0.59488 to 0.59280, saving model to best_model
# Epoch 19/100
# 6400/6400 [==============================] - 11s - loss: 0.6156 - acc: 0.7361 - val_loss: 0.6235 - val_acc: 0.6706
# Epoch 00018: val_loss did not improve
# Epoch 20/100
# 6400/6400 [==============================] - 11s - loss: 0.6139 - acc: 0.7352 - val_loss: 0.5834 - val_acc: 0.6963
# Epoch 00019: val_loss improved from 0.59280 to 0.58337, saving model to best_model
# Epoch 21/100
# 6400/6400 [==============================] - 11s - loss: 0.5985 - acc: 0.7500 - val_loss: 0.5838 - val_acc: 0.6975
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 6400/6400 [==============================] - 11s - loss: 0.5944 - acc: 0.7492 - val_loss: 0.5860 - val_acc: 0.6994
# Epoch 00021: val_loss did not improve
# Epoch 23/100
# 6400/6400 [==============================] - 11s - loss: 0.5916 - acc: 0.7591 - val_loss: 0.5785 - val_acc: 0.7013
# Epoch 00022: val_loss improved from 0.58337 to 0.57850, saving model to best_model
# Epoch 24/100
# 6400/6400 [==============================] - 11s - loss: 0.5861 - acc: 0.7606 - val_loss: 0.5745 - val_acc: 0.7013
# Epoch 00023: val_loss improved from 0.57850 to 0.57446, saving model to best_model
# Epoch 25/100
# 6400/6400 [==============================] - 11s - loss: 0.5842 - acc: 0.7648 - val_loss: 0.5865 - val_acc: 0.7013
# Epoch 00024: val_loss did not improve
# Epoch 26/100
# 6400/6400 [==============================] - 11s - loss: 0.5740 - acc: 0.7741 - val_loss: 0.5742 - val_acc: 0.7100
# Epoch 00025: val_loss improved from 0.57446 to 0.57420, saving model to best_model
# Epoch 27/100
# 6400/6400 [==============================] - 11s - loss: 0.5702 - acc: 0.7825 - val_loss: 0.5898 - val_acc: 0.6813
# Epoch 00026: val_loss did not improve
# Epoch 28/100
# 6400/6400 [==============================] - 11s - loss: 0.5703 - acc: 0.7761 - val_loss: 0.5706 - val_acc: 0.7044
# Epoch 00027: val_loss improved from 0.57420 to 0.57060, saving model to best_model
# Epoch 29/100
# 6400/6400 [==============================] - 11s - loss: 0.5660 - acc: 0.7823 - val_loss: 0.5747 - val_acc: 0.7163
# Epoch 00028: val_loss did not improve
# Epoch 30/100
# 6400/6400 [==============================] - 11s - loss: 0.5628 - acc: 0.7900 - val_loss: 0.5603 - val_acc: 0.7063
# Epoch 00029: val_loss improved from 0.57060 to 0.56026, saving model to best_model
# Epoch 31/100
# 6400/6400 [==============================] - 11s - loss: 0.5489 - acc: 0.8103 - val_loss: 0.5612 - val_acc: 0.7100
# Epoch 00030: val_loss did not improve
# Epoch 32/100
# 6400/6400 [==============================] - 11s - loss: 0.5478 - acc: 0.8105 - val_loss: 0.5711 - val_acc: 0.7081
# Epoch 00031: val_loss did not improve
# Epoch 33/100
# 6400/6400 [==============================] - 11s - loss: 0.5457 - acc: 0.8122 - val_loss: 0.5608 - val_acc: 0.7050
# Epoch 00032: val_loss did not improve
# Epoch 34/100
# 6400/6400 [==============================] - 11s - loss: 0.5412 - acc: 0.8080 - val_loss: 0.5622 - val_acc: 0.7019
# Epoch 00033: val_loss did not improve
# Epoch 35/100
# 6400/6400 [==============================] - 11s - loss: 0.5302 - acc: 0.8311 - val_loss: 0.5665 - val_acc: 0.7013
# Epoch 00034: val_loss did not improve
# Epoch 36/100
# 6400/6400 [==============================] - 11s - loss: 0.5275 - acc: 0.8337 - val_loss: 0.5625 - val_acc: 0.7156
# Epoch 00035: val_loss did not improve
# Epoch 00035: early stopping
# 8000/8000 [==============================] - 7s
# 2000/2000 [==============================] - 1s
# train accuracy: 0.797
# test accuracy: 0.6895
# It took: 434.036532879

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# auc: 0.731162083739

# %%
_,orig_train_y = read_my_data(fname='../prepare_data/naive_feat_vect.csv')
#orig_train_y=orig_train_y[new_idx]
plt.figure(figsize=(9,9))
plt.plot(orig_train_y[N_train:N_train+N_test],test_pred_pr,'.',ms=10)
plt.xlim(-0.05,1.05)
# Out:
# Loading data...
# (-0.05, 1.05)

# %%
from scipy.stats import pearsonr
pearsonr(orig_train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# (0.43382720200316727, 1.4115907833063497e-92)

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3,4],['txn','T','G','C','A'])
