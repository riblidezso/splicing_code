# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int32),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
print train_x.shape

txn_x,txn_y = read_my_data(fname='../prepare_data/txn_feat_vect_200.csv')
print txn_x.shape
# Out:
# Loading data...
# (10097, 1600)
# Loading data...
# (10097, 1600)

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,1600,4))
print train_x.shape

full_x=np.concatenate([train_x,txn_x.reshape(-1,1,1600,1)/2000.0],axis=3)
print full_x.shape
# Out:
# (10097, 1, 1600, 4)
# (10097, 1, 1600, 5)

# %%
train_y=(0.5*(np.sign(train_y-0.5)+1)).astype(np.int8)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2,l1

input_dim=train_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(8,1)
window_size_1=40
window_size_2=40
n_kern_1=40
n_kern_2=50
dense_n=80

model = Sequential()

#Convolution layer 1
model.add(Convolution2D(n_kern_1,window_size_1,5, border_mode='valid',input_shape=(1,input_dim,5)
         ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))

#Convolution layer 2
model.add(Convolution2D(n_kern_2,window_size_2,1, border_mode='valid'
          ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))


#Dense layer
model.add(Flatten())
model.add(Dense(dense_n,activation=activation
               ,W_regularizer=l2(0.01)))
#model.add(Dropout(0.5))


#final layer
model.add(Dense(1, activation='sigmoid'))

#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN not available)
# WARNING (theano.gof.cmodule): ModuleCache.refresh() Found key without dll in cache, deleting it. /afs/krft/user/ribli/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.11-64/tmpSQzgJG/key.pkl
# WARNING:theano.gof.cmodule:ModuleCache.refresh() Found key without dll in cache, deleting it. /afs/krft/user/ribli/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.11-64/tmpSQzgJG/key.pkl
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '25653' (I am process '5410')
# WARNING:theano.gof.compilelock:Overriding existing lock by dead process '25653' (I am process '5410')
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=8000
N_test=2000

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,full_x[:N_train],train_y[:N_train],
    full_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/100
# 6400/6400 [==============================] - 10s - loss: 3.0362 - acc: 0.5922 - val_loss: 0.6607 - val_acc: 0.6288
# Epoch 00000: val_loss improved from inf to 0.66072, saving model to best_model
# Epoch 2/100
# 6400/6400 [==============================] - 10s - loss: 1.9931 - acc: 0.6109 - val_loss: 0.6519 - val_acc: 0.6294
# Epoch 00001: val_loss improved from 0.66072 to 0.65190, saving model to best_model
# Epoch 3/100
# 6400/6400 [==============================] - 10s - loss: 1.5039 - acc: 0.6114 - val_loss: 0.6487 - val_acc: 0.6294
# Epoch 00002: val_loss improved from 0.65190 to 0.64870, saving model to best_model
# Epoch 4/100
# 6400/6400 [==============================] - 10s - loss: 1.2092 - acc: 0.6141 - val_loss: 0.6474 - val_acc: 0.6300
# Epoch 00003: val_loss improved from 0.64870 to 0.64741, saving model to best_model
# Epoch 5/100
# 6400/6400 [==============================] - 10s - loss: 1.0282 - acc: 0.6253 - val_loss: 0.6387 - val_acc: 0.6506
# Epoch 00004: val_loss improved from 0.64741 to 0.63871, saving model to best_model
# Epoch 6/100
# 6400/6400 [==============================] - 10s - loss: 0.9142 - acc: 0.6323 - val_loss: 0.6544 - val_acc: 0.6462
# Epoch 00005: val_loss did not improve
# Epoch 7/100
# 6400/6400 [==============================] - 10s - loss: 0.8392 - acc: 0.6342 - val_loss: 0.6359 - val_acc: 0.6725
# Epoch 00006: val_loss improved from 0.63871 to 0.63588, saving model to best_model
# Epoch 8/100
# 6400/6400 [==============================] - 10s - loss: 0.7855 - acc: 0.6478 - val_loss: 0.6292 - val_acc: 0.6663
# Epoch 00007: val_loss improved from 0.63588 to 0.62918, saving model to best_model
# Epoch 9/100
# 6400/6400 [==============================] - 10s - loss: 0.7454 - acc: 0.6608 - val_loss: 0.6135 - val_acc: 0.6750
# Epoch 00008: val_loss improved from 0.62918 to 0.61352, saving model to best_model
# Epoch 10/100
# 6400/6400 [==============================] - 10s - loss: 0.7149 - acc: 0.6648 - val_loss: 0.6072 - val_acc: 0.6756
# Epoch 00009: val_loss improved from 0.61352 to 0.60722, saving model to best_model
# Epoch 11/100
# 6400/6400 [==============================] - 10s - loss: 0.6930 - acc: 0.6680 - val_loss: 0.5836 - val_acc: 0.6969
# Epoch 00010: val_loss improved from 0.60722 to 0.58356, saving model to best_model
# Epoch 12/100
# 6400/6400 [==============================] - 10s - loss: 0.6699 - acc: 0.6748 - val_loss: 0.5747 - val_acc: 0.6881
# Epoch 00011: val_loss improved from 0.58356 to 0.57468, saving model to best_model
# Epoch 13/100
# 6400/6400 [==============================] - 10s - loss: 0.6610 - acc: 0.6773 - val_loss: 0.5609 - val_acc: 0.7000
# Epoch 00012: val_loss improved from 0.57468 to 0.56092, saving model to best_model
# Epoch 14/100
# 6400/6400 [==============================] - 10s - loss: 0.6446 - acc: 0.6902 - val_loss: 0.5648 - val_acc: 0.6950
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 6400/6400 [==============================] - 10s - loss: 0.6410 - acc: 0.6895 - val_loss: 0.5575 - val_acc: 0.7044
# Epoch 00014: val_loss improved from 0.56092 to 0.55752, saving model to best_model
# Epoch 16/100
# 6400/6400 [==============================] - 10s - loss: 0.6307 - acc: 0.6995 - val_loss: 0.5583 - val_acc: 0.7119
# Epoch 00015: val_loss did not improve
# Epoch 17/100
# 6400/6400 [==============================] - 10s - loss: 0.6169 - acc: 0.7172 - val_loss: 0.5503 - val_acc: 0.7163
# Epoch 00016: val_loss improved from 0.55752 to 0.55035, saving model to best_model
# Epoch 18/100
# 6400/6400 [==============================] - 10s - loss: 0.6145 - acc: 0.7225 - val_loss: 0.5472 - val_acc: 0.7188
# Epoch 00017: val_loss improved from 0.55035 to 0.54720, saving model to best_model
# Epoch 19/100
# 6400/6400 [==============================] - 10s - loss: 0.6184 - acc: 0.7172 - val_loss: 0.5354 - val_acc: 0.7294
# Epoch 00018: val_loss improved from 0.54720 to 0.53545, saving model to best_model
# Epoch 20/100
# 6400/6400 [==============================] - 10s - loss: 0.6014 - acc: 0.7359 - val_loss: 0.5556 - val_acc: 0.7106
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 6400/6400 [==============================] - 10s - loss: 0.5973 - acc: 0.7425 - val_loss: 0.5458 - val_acc: 0.7119
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 6400/6400 [==============================] - 10s - loss: 0.5903 - acc: 0.7488 - val_loss: 0.5391 - val_acc: 0.7156
# Epoch 00021: val_loss did not improve
# Epoch 23/100
# 6400/6400 [==============================] - 10s - loss: 0.5818 - acc: 0.7614 - val_loss: 0.5351 - val_acc: 0.7212
# Epoch 00022: val_loss improved from 0.53545 to 0.53506, saving model to best_model
# Epoch 24/100
# 6400/6400 [==============================] - 10s - loss: 0.5746 - acc: 0.7686 - val_loss: 0.5716 - val_acc: 0.6944
# Epoch 00023: val_loss did not improve
# Epoch 25/100
# 6400/6400 [==============================] - 10s - loss: 0.5670 - acc: 0.7830 - val_loss: 0.5420 - val_acc: 0.7306
# Epoch 00024: val_loss did not improve
# Epoch 26/100
# 6400/6400 [==============================] - 10s - loss: 0.5685 - acc: 0.7837 - val_loss: 0.5476 - val_acc: 0.7137
# Epoch 00025: val_loss did not improve
# Epoch 27/100
# 6400/6400 [==============================] - 10s - loss: 0.5633 - acc: 0.7903 - val_loss: 0.5396 - val_acc: 0.7319
# Epoch 00026: val_loss did not improve
# Epoch 28/100
# 6400/6400 [==============================] - 10s - loss: 0.5406 - acc: 0.8172 - val_loss: 0.5580 - val_acc: 0.7312
# Epoch 00027: val_loss did not improve
# Epoch 29/100
# 6400/6400 [==============================] - 10s - loss: 0.5433 - acc: 0.8178 - val_loss: 0.5444 - val_acc: 0.7275
# Epoch 00028: val_loss did not improve
# Epoch 30/100
# 6400/6400 [==============================] - 10s - loss: 0.5221 - acc: 0.8369 - val_loss: 0.5551 - val_acc: 0.7156
# Epoch 00029: val_loss did not improve
# Epoch 31/100
# 6400/6400 [==============================] - 10s - loss: 0.5113 - acc: 0.8528 - val_loss: 0.5798 - val_acc: 0.7000
# Epoch 00030: val_loss did not improve
# Epoch 00030: early stopping
# 8000/8000 [==============================] - 5s
# 2000/2000 [==============================] - 1s
# train accuracy: 0.768875
# test accuracy: 0.7135
# It took: 340.476695061

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# auc: 0.765823185078

# %%
_,orig_train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
plt.figure(figsize=(9,9))
plt.plot(orig_train_y[N_train:N_train+N_test],test_pred_pr,'.',ms=10)
plt.xlim(-0.05,1.05)
# Out:
# Loading data...
# (-0.05, 1.05)

# %%
from scipy.stats import pearsonr
pearsonr(orig_train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# (0.48220813067472645, 5.584613352728099e-117)

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3,4],['txn','T','G','C','A'])
# Out:
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
