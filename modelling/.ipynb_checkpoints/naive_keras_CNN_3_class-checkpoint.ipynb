# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int8),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect.csv')
print train_x.shape
# Out:
# Loading data...
# (10097, 800)

# %%
#shuffle
new_idx=np.random.permutation(len(train_y))
train_x=train_x[new_idx]
train_y=train_y[new_idx]

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,800,4))
print train_x.shape
# Out:
# (10097, 1, 800, 4)

# %%
#3 way labels
orig_train_y=train_y
train_y=np.zeros([len(train_y),3],dtype=np.int32)
train_y[:,0]=np.int32(orig_train_y<0.1)
train_y[:,1]=np.int32( (orig_train_y>=0.1) & (orig_train_y<0.9)) 
train_y[:,2]=np.int32(orig_train_y>=0.9)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2,l1

input_dim=train_x.shape[2]
activation='relu'
loss='categorical_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(8,1)
window_size_1=40
window_size_2=40
n_kern_1=40
n_kern_2=50
dense_n=80

model = Sequential()

#Convolution layer 1
model.add(Convolution2D(n_kern_1,window_size_1,4, border_mode='valid',input_shape=(1,input_dim,4)
         ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))

#Convolution layer 2
model.add(Convolution2D(n_kern_2,window_size_2,1, border_mode='valid'
          ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))


#Dense layer
model.add(Flatten())
model.add(Dense(dense_n,activation=activation
               ,W_regularizer=l2(0.01)))
#model.add(Dropout(0.5))


#final layer
model.add(Dense(3, activation='softmax'))

#compile model
model.compile(loss=loss,optimizer=optimizer)
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN not available)
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x)
    test_pred_pr=model.predict(test_x)

    #check errors
    #print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    #print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=8000
N_test=2000

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,train_x[:N_train],train_y[:N_train],
    train_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/100
# 6400/6400 [==============================] - 6s - loss: 3.4988 - acc: 0.4364 - val_loss: 1.0671 - val_acc: 0.4612
# Epoch 00000: val_loss improved from inf to 1.06712, saving model to best_model
# Epoch 2/100
# 6400/6400 [==============================] - 6s - loss: 2.6490 - acc: 0.4738 - val_loss: 1.0593 - val_acc: 0.4619
# Epoch 00001: val_loss improved from 1.06712 to 1.05926, saving model to best_model
# Epoch 3/100
# 6400/6400 [==============================] - 6s - loss: 2.2421 - acc: 0.4820 - val_loss: 1.0727 - val_acc: 0.4600
# Epoch 00002: val_loss did not improve
# Epoch 4/100
# 6400/6400 [==============================] - 6s - loss: 1.9628 - acc: 0.4878 - val_loss: 1.0438 - val_acc: 0.4750
# Epoch 00003: val_loss improved from 1.05926 to 1.04381, saving model to best_model
# Epoch 5/100
# 6400/6400 [==============================] - 6s - loss: 1.7581 - acc: 0.5012 - val_loss: 1.0405 - val_acc: 0.4950
# Epoch 00004: val_loss improved from 1.04381 to 1.04055, saving model to best_model
# Epoch 6/100
# 6400/6400 [==============================] - 6s - loss: 1.6034 - acc: 0.5050 - val_loss: 1.0562 - val_acc: 0.4619
# Epoch 00005: val_loss did not improve
# Epoch 7/100
# 6400/6400 [==============================] - 6s - loss: 1.4822 - acc: 0.5083 - val_loss: 1.0167 - val_acc: 0.4956
# Epoch 00006: val_loss improved from 1.04055 to 1.01669, saving model to best_model
# Epoch 8/100
# 6400/6400 [==============================] - 6s - loss: 1.3813 - acc: 0.5242 - val_loss: 1.0188 - val_acc: 0.4806
# Epoch 00007: val_loss did not improve
# Epoch 9/100
# 6400/6400 [==============================] - 6s - loss: 1.3002 - acc: 0.5370 - val_loss: 0.9831 - val_acc: 0.5194
# Epoch 00008: val_loss improved from 1.01669 to 0.98315, saving model to best_model
# Epoch 10/100
# 6400/6400 [==============================] - 6s - loss: 1.2375 - acc: 0.5494 - val_loss: 0.9919 - val_acc: 0.5075
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 6400/6400 [==============================] - 6s - loss: 1.1875 - acc: 0.5570 - val_loss: 0.9729 - val_acc: 0.5300
# Epoch 00010: val_loss improved from 0.98315 to 0.97288, saving model to best_model
# Epoch 12/100
# 6400/6400 [==============================] - 6s - loss: 1.1470 - acc: 0.5627 - val_loss: 0.9606 - val_acc: 0.5444
# Epoch 00011: val_loss improved from 0.97288 to 0.96055, saving model to best_model
# Epoch 13/100
# 6400/6400 [==============================] - 6s - loss: 1.1064 - acc: 0.5847 - val_loss: 0.9619 - val_acc: 0.5406
# Epoch 00012: val_loss did not improve
# Epoch 14/100
# 6400/6400 [==============================] - 6s - loss: 1.0760 - acc: 0.5911 - val_loss: 0.9609 - val_acc: 0.5487
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 6400/6400 [==============================] - 6s - loss: 1.0440 - acc: 0.6078 - val_loss: 0.9572 - val_acc: 0.5494
# Epoch 00014: val_loss improved from 0.96055 to 0.95720, saving model to best_model
# Epoch 16/100
# 6400/6400 [==============================] - 6s - loss: 1.0282 - acc: 0.6150 - val_loss: 0.9587 - val_acc: 0.5544
# Epoch 00015: val_loss did not improve
# Epoch 17/100
# 6400/6400 [==============================] - 6s - loss: 0.9996 - acc: 0.6319 - val_loss: 0.9683 - val_acc: 0.5475
# Epoch 00016: val_loss did not improve
# Epoch 18/100
# 6400/6400 [==============================] - 6s - loss: 0.9776 - acc: 0.6448 - val_loss: 0.9706 - val_acc: 0.5394
# Epoch 00017: val_loss did not improve
# Epoch 19/100
# 6400/6400 [==============================] - 6s - loss: 0.9469 - acc: 0.6672 - val_loss: 0.9723 - val_acc: 0.5444
# Epoch 00018: val_loss did not improve
# Epoch 20/100
# 6400/6400 [==============================] - 6s - loss: 0.9168 - acc: 0.6880 - val_loss: 0.9915 - val_acc: 0.5400
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 6400/6400 [==============================] - 6s - loss: 0.8856 - acc: 0.7120 - val_loss: 1.0158 - val_acc: 0.5350
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 6400/6400 [==============================] - 6s - loss: 0.8624 - acc: 0.7242 - val_loss: 1.0771 - val_acc: 0.5350
# Epoch 00021: val_loss did not improve
# Epoch 23/100
# 6400/6400 [==============================] - 6s - loss: 0.8319 - acc: 0.7488 - val_loss: 1.0870 - val_acc: 0.5156
# Epoch 00022: val_loss did not improve
# Epoch 00022: early stopping
# 8000/8000 [==============================] - 3s
# 2000/2000 [==============================] - 0s
# It took: 168.759510994

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs,i):
    fpr, tpr, thresholds = metrics.roc_curve(y[:,i],probs[:,i])
    auc=metrics.roc_auc_score(y[:,i],probs[:,i])
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr,0)
# Out:
# auc: 0.74503527372

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr,1)
# Out:
# auc: 0.560951500647

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr,2)
# Out:
# auc: 0.726785247714

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3],['A','C','G','T'])
