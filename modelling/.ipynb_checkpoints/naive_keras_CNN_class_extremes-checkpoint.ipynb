# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int8),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect.csv')
print train_x.shape
# Out:
# Loading data...
# (10097, 800)

# %%
#shuffle
new_idx=np.random.permutation(len(train_y))
train_x=train_x[new_idx]
train_y=train_y[new_idx]

# %%
filt_idx= (train_y <0.1) | (train_y > 0.9)
train_x=train_x[filt_idx]
train_y=train_y[filt_idx]

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,800,4))
print train_x.shape
# Out:
# (7478, 1, 800, 4)

# %%
train_y=(0.5*(np.sign(train_y-np.median(train_y))+1)).astype(np.int8)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2,l1

input_dim=train_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(8,1)
window_size_1=40
window_size_2=40
n_kern_1=40
n_kern_2=50
dense_n=80

model = Sequential()

#Convolution layer 1
model.add(Convolution2D(n_kern_1,window_size_1,4, border_mode='valid',input_shape=(1,input_dim,4)
         ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))

#Convolution layer 2
model.add(Convolution2D(n_kern_2,window_size_2,1, border_mode='valid'
          ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))


#Dense layer
model.add(Flatten())
model.add(Dense(dense_n,activation=activation
               ,W_regularizer=l2(0.01)))
#model.add(Dropout(0.5))


#final layer
model.add(Dense(1, activation='sigmoid'))

#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=6000
N_test=1400

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,train_x[:N_train],train_y[:N_train],
    train_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/100
# 4800/4800 [==============================] - 5s - loss: 3.1978 - acc: 0.4973 - val_loss: 0.6902 - val_acc: 0.5158
# Epoch 00000: val_loss improved from inf to 0.69016, saving model to best_model
# Epoch 2/100
# 4800/4800 [==============================] - 5s - loss: 2.3050 - acc: 0.5602 - val_loss: 0.6916 - val_acc: 0.5208
# Epoch 00001: val_loss did not improve
# Epoch 3/100
# 4800/4800 [==============================] - 5s - loss: 1.8194 - acc: 0.5744 - val_loss: 0.6862 - val_acc: 0.5367
# Epoch 00002: val_loss improved from 0.69016 to 0.68620, saving model to best_model
# Epoch 4/100
# 4800/4800 [==============================] - 5s - loss: 1.5061 - acc: 0.6021 - val_loss: 0.6737 - val_acc: 0.5833
# Epoch 00003: val_loss improved from 0.68620 to 0.67372, saving model to best_model
# Epoch 5/100
# 4800/4800 [==============================] - 5s - loss: 1.2914 - acc: 0.6246 - val_loss: 0.6658 - val_acc: 0.6092
# Epoch 00004: val_loss improved from 0.67372 to 0.66578, saving model to best_model
# Epoch 6/100
# 4800/4800 [==============================] - 5s - loss: 1.1306 - acc: 0.6504 - val_loss: 0.6497 - val_acc: 0.6233
# Epoch 00005: val_loss improved from 0.66578 to 0.64972, saving model to best_model
# Epoch 7/100
# 4800/4800 [==============================] - 5s - loss: 1.0216 - acc: 0.6548 - val_loss: 0.6445 - val_acc: 0.6142
# Epoch 00006: val_loss improved from 0.64972 to 0.64450, saving model to best_model
# Epoch 8/100
# 4800/4800 [==============================] - 5s - loss: 0.9315 - acc: 0.6890 - val_loss: 0.6337 - val_acc: 0.6333
# Epoch 00007: val_loss improved from 0.64450 to 0.63368, saving model to best_model
# Epoch 9/100
# 4800/4800 [==============================] - 5s - loss: 0.8683 - acc: 0.6852 - val_loss: 0.6348 - val_acc: 0.6217
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 4800/4800 [==============================] - 5s - loss: 0.8171 - acc: 0.6931 - val_loss: 0.6374 - val_acc: 0.6375
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 4800/4800 [==============================] - 5s - loss: 0.7810 - acc: 0.7040 - val_loss: 0.6206 - val_acc: 0.6458
# Epoch 00010: val_loss improved from 0.63368 to 0.62062, saving model to best_model
# Epoch 12/100
# 4800/4800 [==============================] - 5s - loss: 0.7491 - acc: 0.7106 - val_loss: 0.6188 - val_acc: 0.6442
# Epoch 00011: val_loss improved from 0.62062 to 0.61885, saving model to best_model
# Epoch 13/100
# 4800/4800 [==============================] - 5s - loss: 0.7237 - acc: 0.7240 - val_loss: 0.6233 - val_acc: 0.6400
# Epoch 00012: val_loss did not improve
# Epoch 14/100
# 4800/4800 [==============================] - 5s - loss: 0.6958 - acc: 0.7427 - val_loss: 0.6172 - val_acc: 0.6517
# Epoch 00013: val_loss improved from 0.61885 to 0.61718, saving model to best_model
# Epoch 15/100
# 4800/4800 [==============================] - 5s - loss: 0.6722 - acc: 0.7579 - val_loss: 0.6159 - val_acc: 0.6608
# Epoch 00014: val_loss improved from 0.61718 to 0.61589, saving model to best_model
# Epoch 16/100
# 4800/4800 [==============================] - 5s - loss: 0.6532 - acc: 0.7658 - val_loss: 0.6176 - val_acc: 0.6558
# Epoch 00015: val_loss did not improve
# Epoch 17/100
# 4800/4800 [==============================] - 5s - loss: 0.6305 - acc: 0.7998 - val_loss: 0.6488 - val_acc: 0.6375
# Epoch 00016: val_loss did not improve
# Epoch 18/100
# 4800/4800 [==============================] - 5s - loss: 0.6117 - acc: 0.8092 - val_loss: 0.6397 - val_acc: 0.6242
# Epoch 00017: val_loss did not improve
# Epoch 19/100
# 4800/4800 [==============================] - 5s - loss: 0.5868 - acc: 0.8337 - val_loss: 0.6512 - val_acc: 0.6400
# Epoch 00018: val_loss did not improve
# Epoch 20/100
# 4800/4800 [==============================] - 5s - loss: 0.5541 - acc: 0.8675 - val_loss: 0.6584 - val_acc: 0.6425
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 4800/4800 [==============================] - 5s - loss: 0.5228 - acc: 0.8946 - val_loss: 0.6964 - val_acc: 0.6367
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 4800/4800 [==============================] - 5s - loss: 0.4931 - acc: 0.9202 - val_loss: 0.7090 - val_acc: 0.6333
# Epoch 00021: val_loss did not improve
# Epoch 23/100
# 4800/4800 [==============================] - 5s - loss: 0.4582 - acc: 0.9463 - val_loss: 0.7634 - val_acc: 0.6233
# Epoch 00022: val_loss did not improve
# Epoch 00022: early stopping
# 6000/6000 [==============================] - 2s
# 1400/1400 [==============================] - 0s
# train accuracy: 0.770333333333
# test accuracy: 0.667857142857
# It took: 126.267568827

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# auc: 0.718679510655

# %%
_,orig_train_y = read_my_data(fname='../prepare_data/naive_feat_vect.csv')
orig_train_y=orig_train_y[new_idx][filt_idx]
plt.figure(figsize=(9,9))
plt.plot(orig_train_y[N_train:N_train+N_test],test_pred_pr,'.',ms=10)
plt.xlim(-0.05,1.05)
# Out:
# Loading data...
# (-0.05, 1.05)

# %%
from scipy.stats import pearsonr
pearsonr(orig_train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# (0.48093034789319078, 6.2005644209395624e-82)

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3],['A','C','G','T'])
# Out:
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
