# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int8),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
print train_x.shape
# Out:
# Loading data...
# (10097, 1600)

# %%
#shuffle
#new_idx=np.random.permutation(len(train_y))
#train_x=train_x[new_idx]
#train_y=train_y[new_idx]

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,1600,4))
print train_x.shape
# Out:
# (10097, 1, 1600, 4)

# %%
train_y=(0.5*(np.sign(train_y-0.5)+1)).astype(np.int8)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2,l1

input_dim=train_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(8,1)
window_size_1=40
window_size_2=40
n_kern_1=40
n_kern_2=50
dense_n=80

model = Sequential()

#Convolution layer 1
model.add(Convolution2D(n_kern_1,window_size_1,4, border_mode='valid',input_shape=(1,input_dim,4)
         ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))

#Convolution layer 2
model.add(Convolution2D(n_kern_2,window_size_2,1, border_mode='valid'
          ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))


#Dense layer
model.add(Flatten())
model.add(Dense(dense_n,activation=activation
               ,W_regularizer=l2(0.01)))
#model.add(Dropout(0.5))


#final layer
model.add(Dense(1, activation='sigmoid'))

#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN not available)
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=8000
N_test=2000

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,train_x[:N_train],train_y[:N_train],
    train_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/100
# 6400/6400 [==============================] - 10s - loss: 2.9903 - acc: 0.5925 - val_loss: 0.6599 - val_acc: 0.6306
# Epoch 00000: val_loss improved from inf to 0.65993, saving model to best_model
# Epoch 2/100
# 6400/6400 [==============================] - 10s - loss: 1.9355 - acc: 0.6103 - val_loss: 0.6551 - val_acc: 0.6306
# Epoch 00001: val_loss improved from 0.65993 to 0.65510, saving model to best_model
# Epoch 3/100
# 6400/6400 [==============================] - 10s - loss: 1.4603 - acc: 0.6103 - val_loss: 0.6531 - val_acc: 0.6306
# Epoch 00002: val_loss improved from 0.65510 to 0.65305, saving model to best_model
# Epoch 4/100
# 6400/6400 [==============================] - 10s - loss: 1.1779 - acc: 0.6108 - val_loss: 0.6534 - val_acc: 0.6306
# Epoch 00003: val_loss did not improve
# Epoch 5/100
# 6400/6400 [==============================] - 10s - loss: 1.0014 - acc: 0.6103 - val_loss: 0.6504 - val_acc: 0.6306
# Epoch 00004: val_loss improved from 0.65305 to 0.65039, saving model to best_model
# Epoch 6/100
# 6400/6400 [==============================] - 10s - loss: 0.8884 - acc: 0.6117 - val_loss: 0.6423 - val_acc: 0.6350
# Epoch 00005: val_loss improved from 0.65039 to 0.64230, saving model to best_model
# Epoch 7/100
# 6400/6400 [==============================] - 10s - loss: 0.8169 - acc: 0.6259 - val_loss: 0.6563 - val_acc: 0.6350
# Epoch 00006: val_loss did not improve
# Epoch 8/100
# 6400/6400 [==============================] - 10s - loss: 0.7707 - acc: 0.6238 - val_loss: 0.6362 - val_acc: 0.6763
# Epoch 00007: val_loss improved from 0.64230 to 0.63624, saving model to best_model
# Epoch 9/100
# 6400/6400 [==============================] - 10s - loss: 0.7327 - acc: 0.6406 - val_loss: 0.6242 - val_acc: 0.6687
# Epoch 00008: val_loss improved from 0.63624 to 0.62419, saving model to best_model
# Epoch 10/100
# 6400/6400 [==============================] - 10s - loss: 0.7059 - acc: 0.6464 - val_loss: 0.6067 - val_acc: 0.6937
# Epoch 00009: val_loss improved from 0.62419 to 0.60669, saving model to best_model
# Epoch 11/100
# 6400/6400 [==============================] - 10s - loss: 0.6873 - acc: 0.6517 - val_loss: 0.5917 - val_acc: 0.6975
# Epoch 00010: val_loss improved from 0.60669 to 0.59172, saving model to best_model
# Epoch 12/100
# 6400/6400 [==============================] - 10s - loss: 0.6636 - acc: 0.6644 - val_loss: 0.6062 - val_acc: 0.6869
# Epoch 00011: val_loss did not improve
# Epoch 13/100
# 6400/6400 [==============================] - 10s - loss: 0.6483 - acc: 0.6803 - val_loss: 0.5657 - val_acc: 0.6919
# Epoch 00012: val_loss improved from 0.59172 to 0.56572, saving model to best_model
# Epoch 14/100
# 6400/6400 [==============================] - 10s - loss: 0.6393 - acc: 0.6814 - val_loss: 0.6114 - val_acc: 0.6881
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 6400/6400 [==============================] - 10s - loss: 0.6445 - acc: 0.6802 - val_loss: 0.5589 - val_acc: 0.7044
# Epoch 00014: val_loss improved from 0.56572 to 0.55895, saving model to best_model
# Epoch 16/100
# 6400/6400 [==============================] - 10s - loss: 0.6192 - acc: 0.7014 - val_loss: 0.5463 - val_acc: 0.7200
# Epoch 00015: val_loss improved from 0.55895 to 0.54630, saving model to best_model
# Epoch 17/100
# 6400/6400 [==============================] - 10s - loss: 0.6100 - acc: 0.7086 - val_loss: 0.5889 - val_acc: 0.6750
# Epoch 00016: val_loss did not improve
# Epoch 18/100
# 6400/6400 [==============================] - 10s - loss: 0.6096 - acc: 0.7175 - val_loss: 0.5460 - val_acc: 0.7075
# Epoch 00017: val_loss improved from 0.54630 to 0.54599, saving model to best_model
# Epoch 19/100
# 6400/6400 [==============================] - 10s - loss: 0.5996 - acc: 0.7270 - val_loss: 0.5341 - val_acc: 0.7256
# Epoch 00018: val_loss improved from 0.54599 to 0.53411, saving model to best_model
# Epoch 20/100
# 6400/6400 [==============================] - 10s - loss: 0.5936 - acc: 0.7359 - val_loss: 0.5394 - val_acc: 0.7181
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 6400/6400 [==============================] - 10s - loss: 0.5829 - acc: 0.7469 - val_loss: 0.5379 - val_acc: 0.7175
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 6400/6400 [==============================] - 10s - loss: 0.5811 - acc: 0.7512 - val_loss: 0.5315 - val_acc: 0.7238
# Epoch 00021: val_loss improved from 0.53411 to 0.53148, saving model to best_model
# Epoch 23/100
# 6400/6400 [==============================] - 10s - loss: 0.5674 - acc: 0.7692 - val_loss: 0.5297 - val_acc: 0.7275
# Epoch 00022: val_loss improved from 0.53148 to 0.52970, saving model to best_model
# Epoch 24/100
# 6400/6400 [==============================] - 10s - loss: 0.5713 - acc: 0.7673 - val_loss: 0.5349 - val_acc: 0.7200
# Epoch 00023: val_loss did not improve
# Epoch 25/100
# 6400/6400 [==============================] - 10s - loss: 0.5622 - acc: 0.7738 - val_loss: 0.5479 - val_acc: 0.7188
# Epoch 00024: val_loss did not improve
# Epoch 26/100
# 6400/6400 [==============================] - 10s - loss: 0.5488 - acc: 0.7961 - val_loss: 0.5341 - val_acc: 0.7219
# Epoch 00025: val_loss did not improve
# Epoch 27/100
# 6400/6400 [==============================] - 10s - loss: 0.5413 - acc: 0.8033 - val_loss: 0.5805 - val_acc: 0.6987
# Epoch 00026: val_loss did not improve
# Epoch 28/100
# 6400/6400 [==============================] - 10s - loss: 0.5401 - acc: 0.8139 - val_loss: 0.5471 - val_acc: 0.7119
# Epoch 00027: val_loss did not improve
# Epoch 29/100
# 6400/6400 [==============================] - 10s - loss: 0.5281 - acc: 0.8191 - val_loss: 0.5473 - val_acc: 0.7219
# Epoch 00028: val_loss did not improve
# Epoch 30/100
# 6400/6400 [==============================] - 10s - loss: 0.5094 - acc: 0.8402 - val_loss: 0.5774 - val_acc: 0.7069
# Epoch 00029: val_loss did not improve
# Epoch 31/100
# 6400/6400 [==============================] - 10s - loss: 0.5002 - acc: 0.8420 - val_loss: 0.5797 - val_acc: 0.7031
# Epoch 00030: val_loss did not improve
# Epoch 00030: early stopping
# 8000/8000 [==============================] - 4s
# 2000/2000 [==============================] - 1s
# train accuracy: 0.777375
# test accuracy: 0.702
# It took: 323.391505957

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# auc: 0.758371305547

# %%
_,orig_train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
#orig_train_y=orig_train_y[new_idx]
plt.figure(figsize=(9,9))
plt.plot(orig_train_y[N_train:N_train+N_test],test_pred_pr,'.',ms=10)
plt.xlim(-0.05,1.05)
# Out:
# Loading data...
# (-0.05, 1.05)

# %%
from scipy.stats import pearsonr
pearsonr(orig_train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# (0.47227982120066597, 1.2031009520496189e-111)

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3],['A','C','G','T'])
# Out:
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
