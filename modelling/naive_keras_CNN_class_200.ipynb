# %%
import os,subprocess
workdir='/mnt/Data1/ribli/splicing_code/modelling/'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

#theano gpu
os.environ['THEANO_FLAGS']='device=gpu'

#import sys
#sys.path.append('../my_modules')
#from loading_utils import read_my_data

import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.style.use('ggplot')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import gc

def read_my_data(fname,**kwargs):
    """Load my data from file into np.arrays.
    
    I had to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',header=None)
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    #probe_id=x[0]
    #y=x.iloc[:,-1].values.astype(np.int8)
    #x=x.iloc[:,1:-1].values.astype(np.int8)
    #return probe_id,x,y
    
    return x.iloc[:,:-1].values.astype(np.int8),x.iloc[:,-1].values.astype(np.float64)

# %%
train_x,train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
print train_x.shape
# Out:
# Loading data...
# (10097, 1600)

# %%
#shuffle
new_idx=np.random.permutation(len(train_y))
train_x=train_x[new_idx]
train_y=train_y[new_idx]

# %%
#make it image like
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
train_x=lb.fit_transform(np.concatenate([train_x.flatten()])).reshape((-1,1,1600,4))
print train_x.shape
# Out:
# (10097, 1, 1600, 4)

# %%
train_y=(0.5*(np.sign(train_y-0.5)+1)).astype(np.int8)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2,l1

input_dim=train_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adam'
init='glorot_normal'
pool_size=(8,1)
window_size_1=40
window_size_2=40
n_kern_1=40
n_kern_2=50
dense_n=80

model = Sequential()

#Convolution layer 1
model.add(Convolution2D(n_kern_1,window_size_1,4, border_mode='valid',input_shape=(1,input_dim,4)
         ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))

#Convolution layer 2
model.add(Convolution2D(n_kern_2,window_size_2,1, border_mode='valid'
          ,W_regularizer=l2(0.01))
         )
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))


#Dense layer
model.add(Flatten())
model.add(Dense(dense_n,activation=activation
               ,W_regularizer=l2(0.01)))
#model.add(Dropout(0.5))


#final layer
model.add(Dense(1, activation='sigmoid'))

#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN not available)
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
N_train=8000
N_test=2000

train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,train_x[:N_train],train_y[:N_train],
    train_x[N_train:N_train+N_test],train_y[N_train:N_train+N_test],
    validation_split=0.2)
# Out:
# Train on 6400 samples, validate on 1600 samples
# Epoch 1/100
# 6400/6400 [==============================] - 10s - loss: 2.9465 - acc: 0.5998 - val_loss: 0.6669 - val_acc: 0.6112
# Epoch 00000: val_loss improved from inf to 0.66685, saving model to best_model
# Epoch 2/100
# 6400/6400 [==============================] - 10s - loss: 1.8892 - acc: 0.6133 - val_loss: 0.6612 - val_acc: 0.6112
# Epoch 00001: val_loss improved from 0.66685 to 0.66124, saving model to best_model
# Epoch 3/100
# 6400/6400 [==============================] - 10s - loss: 1.4344 - acc: 0.6133 - val_loss: 0.6536 - val_acc: 0.6112
# Epoch 00002: val_loss improved from 0.66124 to 0.65357, saving model to best_model
# Epoch 4/100
# 6400/6400 [==============================] - 10s - loss: 1.1637 - acc: 0.6172 - val_loss: 0.6739 - val_acc: 0.6112
# Epoch 00003: val_loss did not improve
# Epoch 5/100
# 6400/6400 [==============================] - 10s - loss: 1.0019 - acc: 0.6192 - val_loss: 0.6501 - val_acc: 0.6125
# Epoch 00004: val_loss improved from 0.65357 to 0.65008, saving model to best_model
# Epoch 6/100
# 6400/6400 [==============================] - 10s - loss: 0.8871 - acc: 0.6238 - val_loss: 0.6432 - val_acc: 0.6319
# Epoch 00005: val_loss improved from 0.65008 to 0.64315, saving model to best_model
# Epoch 7/100
# 6400/6400 [==============================] - 10s - loss: 0.8146 - acc: 0.6358 - val_loss: 0.6366 - val_acc: 0.6462
# Epoch 00006: val_loss improved from 0.64315 to 0.63661, saving model to best_model
# Epoch 8/100
# 6400/6400 [==============================] - 10s - loss: 0.7678 - acc: 0.6486 - val_loss: 0.6294 - val_acc: 0.6512
# Epoch 00007: val_loss improved from 0.63661 to 0.62936, saving model to best_model
# Epoch 9/100
# 6400/6400 [==============================] - 10s - loss: 0.7270 - acc: 0.6628 - val_loss: 0.6115 - val_acc: 0.6687
# Epoch 00008: val_loss improved from 0.62936 to 0.61151, saving model to best_model
# Epoch 10/100
# 6400/6400 [==============================] - 9s - loss: 0.6978 - acc: 0.6653 - val_loss: 0.6002 - val_acc: 0.6681
# Epoch 00009: val_loss improved from 0.61151 to 0.60018, saving model to best_model
# Epoch 11/100
# 6400/6400 [==============================] - 9s - loss: 0.6651 - acc: 0.6822 - val_loss: 0.6052 - val_acc: 0.6650
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 6400/6400 [==============================] - 9s - loss: 0.6479 - acc: 0.6969 - val_loss: 0.5828 - val_acc: 0.6837
# Epoch 00011: val_loss improved from 0.60018 to 0.58278, saving model to best_model
# Epoch 13/100
# 6400/6400 [==============================] - 9s - loss: 0.6320 - acc: 0.7034 - val_loss: 0.5800 - val_acc: 0.6756
# Epoch 00012: val_loss improved from 0.58278 to 0.58002, saving model to best_model
# Epoch 14/100
# 6400/6400 [==============================] - 9s - loss: 0.6171 - acc: 0.7184 - val_loss: 0.5702 - val_acc: 0.6919
# Epoch 00013: val_loss improved from 0.58002 to 0.57018, saving model to best_model
# Epoch 15/100
# 6400/6400 [==============================] - 9s - loss: 0.6082 - acc: 0.7250 - val_loss: 0.5713 - val_acc: 0.6925
# Epoch 00014: val_loss did not improve
# Epoch 16/100
# 6400/6400 [==============================] - 9s - loss: 0.5975 - acc: 0.7408 - val_loss: 0.5726 - val_acc: 0.6775
# Epoch 00015: val_loss did not improve
# Epoch 17/100
# 6400/6400 [==============================] - 9s - loss: 0.5845 - acc: 0.7558 - val_loss: 0.5681 - val_acc: 0.6900
# Epoch 00016: val_loss improved from 0.57018 to 0.56811, saving model to best_model
# Epoch 18/100
# 6400/6400 [==============================] - 9s - loss: 0.5803 - acc: 0.7612 - val_loss: 0.5632 - val_acc: 0.7025
# Epoch 00017: val_loss improved from 0.56811 to 0.56320, saving model to best_model
# Epoch 19/100
# 6400/6400 [==============================] - 9s - loss: 0.5643 - acc: 0.7859 - val_loss: 0.5880 - val_acc: 0.6675
# Epoch 00018: val_loss did not improve
# Epoch 20/100
# 6400/6400 [==============================] - 9s - loss: 0.5542 - acc: 0.7950 - val_loss: 0.5752 - val_acc: 0.6950
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 6400/6400 [==============================] - 9s - loss: 0.5421 - acc: 0.8142 - val_loss: 0.5815 - val_acc: 0.6825
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 6400/6400 [==============================] - 9s - loss: 0.5262 - acc: 0.8287 - val_loss: 0.6118 - val_acc: 0.6975
# Epoch 00021: val_loss did not improve
# Epoch 23/100
# 6400/6400 [==============================] - 9s - loss: 0.5070 - acc: 0.8534 - val_loss: 0.6137 - val_acc: 0.7006
# Epoch 00022: val_loss did not improve
# Epoch 24/100
# 6400/6400 [==============================] - 9s - loss: 0.4915 - acc: 0.8706 - val_loss: 0.6284 - val_acc: 0.6937
# Epoch 00023: val_loss did not improve
# Epoch 25/100
# 6400/6400 [==============================] - 9s - loss: 0.4722 - acc: 0.8911 - val_loss: 0.6357 - val_acc: 0.6987
# Epoch 00024: val_loss did not improve
# Epoch 26/100
# 6400/6400 [==============================] - 9s - loss: 0.4387 - acc: 0.9200 - val_loss: 0.6782 - val_acc: 0.6919
# Epoch 00025: val_loss did not improve
# Epoch 00025: early stopping
# 8000/8000 [==============================] - 4s
# 2000/2000 [==============================] - 1s
# train accuracy: 0.783125
# test accuracy: 0.7275
# It took: 273.340943098

# %% [markdown]
# ### roc auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# auc: 0.771360108181

# %%
_,orig_train_y = read_my_data(fname='../prepare_data/naive_feat_vect_200.csv')
orig_train_y=orig_train_y[new_idx]
plt.figure(figsize=(9,9))
plt.plot(orig_train_y[N_train:N_train+N_test],test_pred_pr,'.',ms=10)
plt.xlim(-0.05,1.05)
# Out:
# Loading data...
# (-0.05, 1.05)

# %%
from scipy.stats import pearsonr
pearsonr(orig_train_y[N_train:N_train+N_test],test_pred_pr)
# Out:
# (0.4753365659277744, 2.8640331824017583e-113)

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

# %%
for w, in weigths:
    plt.figure(figsize=(16,3))
    plt.imshow(w.T,interpolation='none',aspect=1.5,cmap='Blues')
    plt.colorbar()
    dump=plt.yticks([0,1,2,3],['A','C','G','T'])
# Out:
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
